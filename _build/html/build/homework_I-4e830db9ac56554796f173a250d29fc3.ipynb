# %% [markdown]
# ### Homework I

# %% [markdown]
# 1. A sum of $\$9,000$ paid into a bank account for 61 days to attract simple interest.  The account has $\$9,200$ at the end of the 61 days, what was the interest rate?

# %% [markdown]
# 2. Find the principal to be deposited in an acount attracting siple interst at 8% if \$1,000  is needed after three months (91 days).

# %% [markdown]
# 3. Find and compare the future value after two years of a deposit of \$100 attracting interest at 10% compounded
#    - annually
#    - semi-annually

# %% [markdown]
# 4. What initial investment subject to annual compounding at 12% interest is needed to produce \$1,000 after two years?

# %% [markdown]
# 5. Suppose that you deposit \$1,200 at the end of each year for 40 years subject to annual compounding at a constant rate of 5%.  Find the balance after 40 years.
